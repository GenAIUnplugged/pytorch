# %% [markdown]
# <a href="https://colab.research.google.com/github/GenAIUnplugged/pytorch/blob/main/Bounding_Boxes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import numpy as np
from torchvision.transforms import transforms
from PIL import Image
import matplotlib.pyplot as plt
from torchvision.utils import draw_bounding_boxes

# %%
image = Image.open("/content/lion.jpg")

# %%
preprocess = transforms.Compose([
  transforms.Resize(224),
  transforms.ToTensor()
])

# %%
img = preprocess(image)

# %%
img.shape
# Out:
# torch.Size([3, 244, 224])

# %%
img.permute(1,2,0).shape
# Out:
# torch.Size([244, 224, 3])

# %%
plt.imshow(img.permute(1,2,0))

# %%
bbox = torch.tensor([75,75,150,150])

# %%
bbox
# Out:
# tensor([ 75,  75, 150, 150])

# %%
result = draw_bounding_boxes(image=img,boxes=bbox.unsqueeze(0),width=3,colors='red')

# %%
result.shape
# Out:
# torch.Size([3, 244, 224])

# %%
plt.imshow(result.permute(1,2,0))
